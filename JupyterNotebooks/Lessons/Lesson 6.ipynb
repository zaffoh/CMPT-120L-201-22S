# %% [markdown]
# # Introduction to Programming
#
# Topics for today will include:
# - Bash
# - Pip
# - Flask
# - Bootstrap

# %% [markdown]
# # Bash (Bourne Again Shell)
# ---
# So we've visited this a few times at this point but there's no more avoiding it. Bash is the default for a lot of terminals. These commands should work on both systems. The only one that's different is to create a file. So we need to be comfortable navigating our file systems. This becomes relevant as we start to develop more pure scripts we have to move away from our GUIs.
#
# ## Key Commands
# ---
# These commands are the some of the basic ones used to navigate around. This is a little more complex on Windows depending on whether or not you decide to used WSL (Windows Subsystem for Linux). That being said I'm assuming that you're using powershell if you're on Windows. Before we get into that we're going to talk paths. Below we have a couple paths and what you need to understand is that `/` and `\` denotes that you're going down a level in the folder or that you're going inside of that folder.
#
# ### Mac
# ```
# /Users/kippins/Code/CMPT-120L-910-20F
# ```
# Top Level Folder: Users, then the arrows mean were going into the folder. Similar to as if you double clicked on it.
# Users -> kippins -> Code -> CMPT-120L-910-20F
# <br>
# <br>
# <br>
#
# ### Windows
# ```
# C:\Users\Kippins\Desktop
# ```
# Top Level Folder: Users, then the arrows mean were going into the folder. Similar to as if you double clicked on it.
# Users -> Kippins -> Desktop
# <br>
# <br>
# <br>
#
# **List Files and Folders (ls)**
#
# This command allows us to see the files in the folder we're currently in.
# ```
# (base) kippins@Kippins-MacBook-Pro ➜ ~/Code/CMPT-120L-910-20F git:(master) ✗ ls
# Assignments      Git.md           JupyterNotebooks LICENSE          QuickDemos       README.md        SemesterProject
# (base) kippins@Kippins-MacBook-Pro ➜ ~/Code/CMPT-120L-910-20F git:(master) ✗
# ```
#
# **Present Working Directory (pwd)**
#
# This command is used to see your current location in the terminal.
# ```
# (base) kippins@Kippins-MacBook-Pro ➜ ~/Code/CMPT-120L-910-20F git:(master) ✗ pwd
# /Users/kippins/Code/CMPT-120L-910-20F
# (base) kippins@Kippins-MacBook-Pro ➜ ~/Code/CMPT-120L-910-20F git:(master) ✗
# ```
#
# **Change Directories (cd)**
#
# This is used to move from folder to folder.
# ```
# (base) kippins@Kippins-MacBook-Pro ➜ ~/Code/CMPT-120L-910-20F git:(master) ✗ ls
# Assignments      Git.md           JupyterNotebooks LICENSE          QuickDemos       README.md        SemesterProject
# (base) kippins@Kippins-MacBook-Pro ➜ ~/Code/CMPT-120L-910-20F git:(master) ✗ cd Assignments
# (base) kippins@Kippins-MacBook-Pro ➜ ~/Code/CMPT-120L-910-20F/Assignments git:(master) ✗ ls
# Assgnment 3          Assgnment 3 Solution Assignment 4         Assignment 5         Assignment 6
# (base) kippins@Kippins-MacBook-Pro ➜ ~/Code/CMPT-120L-910-20F/Assignments git:(master) ✗
# (base) kippins@Kippins-MacBook-Pro ➜ ~/Code/CMPT-120L-910-20F/Assignments git:(master) ✗ cd ..
# (base) kippins@Kippins-MacBook-Pro ➜ ~/Code/CMPT-120L-910-20F git:(master) ✗
# ```
#
# **Create a File (touch (Mac)) or (ni (Windows))**
#
# This is used to create a file.
# ```
# (base) kippins@Kippins-MacBook-Pro ➜ ~/Code/CMPT-120L-910-20F git:(master) ✗ ls
# Assignments      Git.md           JupyterNotebooks LICENSE          QuickDemos       README.md        SemesterProject
# (base) kippins@Kippins-MacBook-Pro ➜ ~/Code/CMPT-120L-910-20F git:(master) ✗ touch demo_file
# (base) kippins@Kippins-MacBook-Pro ➜ ~/Code/CMPT-120L-910-20F git:(master) ✗ ls
# Assignments      Git.md           JupyterNotebooks LICENSE          QuickDemos       README.md        SemesterProject  demo_file
# (base) kippins@Kippins-MacBook-Pro ➜ ~/Code/CMPT-120L-910-20F git:(master) ✗
# ```
#
# **Make Directory (mkdir)**
#
# This is used to create a directory.
# ```
# (base) kippins@Kippins-MacBook-Pro ➜ ~/Code/CMPT-120L-910-20F git:(master) ✗ mkdir demo_dir
# (base) kippins@Kippins-MacBook-Pro ➜ ~/Code/CMPT-120L-910-20F git:(master) ✗ ls
# Assignments      Git.md           JupyterNotebooks LICENSE          QuickDemos       README.md        SemesterProject  demo_dir
# ```
#
# **Remove a File or Folder (rm)**
#
# This is how we remove a file
# ```
# (base) kippins@Kippins-MacBook-Pro ➜ ~/Code/CMPT-120L-910-20F git:(master) ✗ ls
# Assignments      Git.md           JupyterNotebooks LICENSE          QuickDemos       README.md        SemesterProject  demo_file
# (base) kippins@Kippins-MacBook-Pro ➜ ~/Code/CMPT-120L-910-20F git:(master) ✗ rm demo_file
# (base) kippins@Kippins-MacBook-Pro ➜ ~/Code/CMPT-120L-910-20F git:(master) ✗ ls
# Assignments      Git.md           JupyterNotebooks LICENSE          QuickDemos       README.md        SemesterProject
# (base) kippins@Kippins-MacBook-Pro ➜ ~/Code/CMPT-120L-910-20F git:(master) ✗
# ```
#
# This is how we remove a folder
#
# **Note: For a folder we need to add flags before the name of the folder we want to get rid of. -r is a flag that means recursive and -f is a flag that means force. Please be careful with this command. Be VERY sure of what you're deleting.*
# ```
# (base) kippins@Kippins-MacBook-Pro ➜ ~/Code/CMPT-120L-910-20F git:(master) ✗ mkdir demo_dir
# (base) kippins@Kippins-MacBook-Pro ➜ ~/Code/CMPT-120L-910-20F git:(master) ✗ ls
# Assignments      Git.md           JupyterNotebooks LICENSE          QuickDemos       README.md        SemesterProject  demo_dir
# (base) kippins@Kippins-MacBook-Pro ➜ ~/Code/CMPT-120L-910-20F git:(master) ✗ rm demo_dir
# rm: demo_dir: is a directory
# (base) kippins@Kippins-MacBook-Pro ➜ ~/Code/CMPT-120L-910-20F git:(master) ✗ rm -rf demo_dir
# (base) kippins@Kippins-MacBook-Pro ➜ ~/Code/CMPT-120L-910-20F git:(master) ✗
# ```
#
# **Run a Python File (python3)**
# ```
# (base) kippins@Kippins-MacBook-Pro ➜ ~/Code/CMPT-120L-910-20F/QuickDemos git:(master) ✗ ls
# Assignment 4.py HelloWorld.java HelloWorld.py   Lesson 3 Web    example.py
# (base) kippins@Kippins-MacBook-Pro ➜ ~/Code/CMPT-120L-910-20F/QuickDemos git:(master) ✗ python3 HelloWorld.py
# Hello World
# Hello Aaron!
# (base) kippins@Kippins-MacBook-Pro ➜ ~/Code/CMPT-120L-910-20F/QuickDemos git:(master) ✗
# ```
#
# All of these commands are going to be integral moving forward.

# %% [markdown]
# # [Pip](https://pip.pypa.io/en/stable/)
# ---
# Pip is pythons package installer this is something that is often used to get us packages that we need. We'll be grabbing one in a moment when we pick up Flask. Pip is an amazing tool that grants us access to the power of Python. For data science look into the following link [here](https://realpython.com/tutorials/data-science/)
#
# The libraries that are available are hosted here at [PyPi](https://pypi.org). These are both massive resources that we'll be using going forward.
#
# To be safe we'll use `pip3` when applicable.
#
# Typically it'll be `pip3 install <package-name>`

# %% [markdown]
# # [PyGame](https://www.pygame.org/news)
# ----------------------------------------------------------------
# As we've talked about in the past class or two we want to make a game for our final project. Since Unity was a little too drag and drop at a high level we're going to look into PyGame. We want to see what it'll take for us to get started with PyGame. First thing that we need to do is install PyGame and get the library onto our machines. We can do that using either:
#
# ```
# pip3 install pygame --user
# ```
# or
# ```
# python3 -m pip install -U pygame --user
# ```

# %% [markdown]
# # [Unity Hub](https://unity.com)
# ----------------------------------------------------------------
# Although we're not going to use it, I encourage you all to still go and play around with Unity. We can take a brief look at some of the stuff that I found!

# %% [markdown]
# # [Flask (Older Content But Still Cool!)](https://flask.palletsprojects.com/en/1.1.x/)
# ---
# Flask is going to be our muse for the next 8 weeks or so. Flask is the back end server that we'll be using that is python based. To install it we'll run `pip3 install Flask`
#
# We're going to be following [this tutorial](https://flask.palletsprojects.com/en/1.1.x/quickstart/) for today and you'll be doing something similar in your lab for this week.

# %% [markdown]
# # [Bootstrap Grid (Older Content But Still Cool!)](https://getbootstrap.com/docs/4.5/layout/grid/)
# ---
# So to end we're going to chat a little bit about the Bootstrap grid system. The Bootstrap Grid is made up of 12 columns and we'll use that to divy up and create content on a page.
